# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('Odin123', '5Ba7VLNrZsqtUXUatHiZ')

import pandas as pd
import numpy as np
import csv
import zipfile
import re

import random
import matplotlib as mpl
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from scipy.misc import imread
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from wordcloud import WordCloud, STOPWORDS


# %matplotlib inline
filepath = "../resources/food.csv.zip"
zf = zipfile.ZipFile(filepath)
food = pd.read_csv(zf.open('food.csv'), parse_dates=True, dtype=object, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',10)

# get a list of all candy tags and combinations of candy tags, get all foods who's tags are in that list.
# bad approach because it's slow and if something contains candy tags + non-candy tags (e.g. 'desserts, water')
# it falls through the cracks. Sadly I can't figure out how to do
# "for candy_tag in candy_tags: get items where candy_tag in food['categories_tags']"

from itertools import combinations

candy_tags = ["en:sugary-snacks", "en:desserts", "en:candies", "en:chocolates", "en:pies", "en:puddings", 
 "en:biscuits-and-cakes", "en:confectioneries", "en:chocolate-chip-cookies", "en:chocolate-block", 
 "en:jelly-crystals", "en:carrot-cake", "en:chocolate-covered-muesli-bar"]
augmented_tags = candy_tags

for i in range(2, 4):
    augmented_tags += [",".join(map(str, comb)) for comb in combinations(candy_tags, i)]

#augmented_tags
tagged_candies = food[food['categories_tags'].isin(augmented_tags)]

#tagged_candies = [item for item in food if not set(augmented_tags).isdisjoint(item['categories_tags'])]

# %%
cols_to_load = ["sugars_100g", "energy_100g", "salt_100g", "fat_100g", "proteins_100g", "carbohydrates_100g", "categories_en", "code"]
clean_food = pd.read_csv(zf.open('food.csv'), parse_dates=True, dtype=object, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8', 
                                      usecols=cols_to_load)
clean_food = clean_food.apply(pd.to_numeric, errors='ignore')
 # remove columns with NA values
clean_food = clean_food.dropna()

# %%
### Machine Learning Stuff ###
from sklearn_pandas import DataFrameMapper
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
#pd.to_numeric(tagged_candies, errors='coerce')
#tagged_candies[['sugars_100g','fat_100g', 'salt_100g', 'energy_100g']] = tagged_candies[['sugars_100g','fat_100g', 'salt_100g', 'energy_100g']].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# TODO: use .apply to split tags and find all candies, use sklean-pandas to start some machine learning stuffs

# %%
def predict_chocolate(df):
    print("removing columns with NaN, might prevent aligning original df with predictions; pls remove NaN columns ahead of time")
    # turn everything you can into floats and remove columns with NA values
    df = df.apply(pd.to_numeric, errors='ignore')
    df = df.dropna(subset=["fat_100g", "sugars_100g", "salt_100g", "energy_100g"])

    length = len(df["fat_100g"].values)
    
    fat_data = df["fat_100g"].values.reshape(length, 1)
    sugars_data = df["sugars_100g"].values.reshape(length, 1)
    salt_data = df["salt_100g"].values.reshape(length, 1)
    energy_data = df["energy_100g"].values.reshape(length, 1)
    
    # combine training data and flatten label-column to list
    final_data = np.hstack([fat_data, sugars_data, salt_data, energy_data])
        
    
    return forest.predict(final_data)

# %%
def plot_attributes(id_string, name, use_only_chocs=True):
    if use_only_chocs:
        selected_chocs = chocs_only[chocs_only['categories_en'].str.contains(id_string)]
    else:
        cols_to_load = ["sugars_100g", "energy_100g", "salt_100g", "fat_100g", "proteins_100g", "carbohydrates_100g", 'categories_en']
        food = pd.read_csv(zf.open('food.csv'), parse_dates=True, dtype=object, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8', 
                                      usecols=cols_to_load)
        # turn all objects (aside from categories) into floats
        food = food.apply(pd.to_numeric, errors='ignore')
        # remove columns with NA values
        food = food.dropna()
        
        selected_chocs = food[food['categories_en'].str.contains(id_string)]  # shouldnt be called selected_chocs since its all food
        
    print(len(selected_chocs))
    #print(dark_chocs)

    trace1 = go.Scatter(
        x = selected_chocs['sugars_100g'],
        y = [85 for x in range(len(selected_chocs['sugars_100g']))],
        mode = 'markers',
        name = "x: sugar per 100g",
        marker = dict(
            color = 'rgba(152, 0, 0, .8)'
        )
    )
    
    trace2 = go.Scatter(
        x = selected_chocs["fat_100g"],
        y = [70 for x in range(len(selected_chocs['fat_100g']))],
        mode = 'markers',
        name = "x: fat per 100g",
        marker = dict(
            color = 'rgba(152, 152, 0, .8)'
        )
    )
    
    trace3 = go.Scatter(
        x = selected_chocs["salt_100g"],
        y = [55 for x in range(len(selected_chocs['salt_100g']))],
        mode = 'markers',
        name = "x: salt per 100g",
        marker = dict(
            color = 'rgba(188, 113, 255, .9)'
        )
    )
    
    trace4 = go.Scatter(
        x = selected_chocs["carbohydrates_100g"],
        y = [40 for x in range(len(selected_chocs['carbohydrates_100g']))],
        mode = 'markers',
        name = "x: carbohydrates per 100g",
        marker = dict(
            color = 'rgba(100, 100, 255, .9)'
        )
    )
    
    trace5 = go.Scatter(
        x = selected_chocs['proteins_100g'],
        y = [25 for x in range(len(selected_chocs['proteins_100g']))],
        mode = 'markers',
        name = "x: proteins per 100g",
        marker = dict(
            #size = 10,
            color = 'rgba(79, 190, 96, .9)'
           # line = dict(
           #     width = 2,
           #     color = 'rgb(0, 0, 0)'
           # )
        )
    )

    layout = go.Layout(
        title= name +  ': attribute clusters',
        xaxis= dict(
            range=[0, 100],
            title="x-axis"
        ),
        yaxis=dict(
            range=[0, 100],
            title="y-axis"
        )
    )

    data = [trace1, trace2, trace3, trace4, trace5]

    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, filename=name + '-attribute_scatter')

# %%
# predcols: columns used to predict [str list]
# label_cond: substr that has to be part of label for labels_to_predict [str]
# forest_count: number of trees to use in forest
# custom_df: dataframe to use, None for standard food.csv
# returns tuple (forest, y_test, X_test)
def train_forest(predcols, label_cond, forest_count = 100, custom_df = None):
    cols_to_load = predcols + ["categories_en"]
    
    forest = RandomForestClassifier(n_estimators = forest_count, random_state = 22)
    
    if custom_df is None:
        prediction_features = pd.read_csv(zf.open('food.csv'), parse_dates=True, dtype=object, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8', 
                                      usecols=cols_to_load)
    else:
        prediction_features = custom_df
    
    #print(prediction_features)
    
    # turn all objects (aside from categories) into floats
    prediction_features = prediction_features.apply(pd.to_numeric, errors='ignore')

    # remove columns with NA values
    prediction_features = prediction_features.dropna()
    # print(prediction_features)

    # put labels in separate dataframe
    labels_to_predict = prediction_features["categories_en"]
    prediction_features.drop('categories_en', axis=1, inplace=True)

    # turn labels_to_predict from a string-dataframe into a numbers-dataframe (indicating whether the word 'chocolate' is in categories with 1 or 0)
    indeces = []
    values = []
    for index, value in labels_to_predict.iteritems():
        indeces.append(index)
        if label_cond in value:
            values.append(1.0)
        else:
            values.append(0.0)

    predict_labels_id = "is_" + label_cond

    values = np.asarray(values)  # turn values into np array
    labels_dict = {predict_labels_id : pd.Series(values, indeces)} 

    labels_to_predict = pd.DataFrame(labels_dict)

    #for index, value in labels_to_predict[predict_labels_id].iteritems():
    #    print(value)

    # TODO: need to split this into 3 sets: training, validation(to tweak), test
    X_train, X_test, y_train, y_test = train_test_split(prediction_features, labels_to_predict, random_state=22)


    X_train_len = len(X_train[predcols[0]].values)
    y_train_len = len(y_train[predict_labels_id].values)
    
    train_data = []
    for attribute in predcols:
        train_data.append(X_train[attribute].values.reshape(X_train_len, 1))

    # combine training data and flatten label-column to list
    train_data = np.hstack(train_data)
    final_labels_train = np.ravel(y_train)

    forest = forest.fit(train_data, final_labels_train)

    # determine cross validation score
    scores = cross_val_score(forest, train_data, final_labels_train, scoring='accuracy', cv = 5)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    
    return (forest, y_test, X_test)

#def predict(forest, df, predcols):
#    print("removing columns with NaN, might prevent aligning original df with predictions; pls remove NaN columns ahead of time")
#    # turn everything you can into floats and remove columns with NA values
#    df = df.apply(pd.to_numeric, errors='ignore')
#    df = df.dropna(subset=predcols)

#    length = len(df[predcols[0]].values)
    
#    pred_data = []
#    for attribute in predcols:
#        pred_data.append(df[attribute].values.reshape(length, 1))
    
    # combine training data and flatten label-column to list
#    final_data = np.hstack(pred_data)
        
#    return forest.predict(final_data)

# %%
def is_in_food_list(items, item):
    for i in items:
        if i["code"] == item["code"]:
            return True
    return False

def predict(forest, df, predcols):
    length = len(df[predcols[0]].values)
    
    pred_data = []
    for attribute in predcols:
        pred_data.append(df[attribute].values.reshape(length, 1))
    
    # combine training data and flatten label-column to list
    final_data = np.hstack(pred_data)
        
    return forest.predict(final_data)

# call with list of forests, df, list of predcols (one for each forest!)
# should return a list with all items that were predicted to be a kind of chocolate by the forests
def predict_chocolate_unified(forests, df, predcols_list):
    pred_data = []
    for i in range(len(forests)):
        predicted_by_this_forest = predict(forests[i], df, predcols_list[i])
        for j in range(len(df)):
            if (predicted_by_this_forest[j] == 1):
                if not is_in_food_list(pred_data, df.iloc[j]):
                    pred_data.append(df.iloc[j])
            
    print(pred_data)
    return pred_data

# %%
# 100 trees, seed for rnd-ness is 22
forest = RandomForestClassifier(n_estimators = 100, random_state = 22)

prediction_features = pd.read_csv(zf.open('food.csv'), parse_dates=True, dtype=object, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8', 
                                  usecols=["sugars_100g", 
                                           "fat_100g",
                                           "salt_100g",
                                           "energy_100g",
                                           "categories_en",
                                          ])

# turn all objects (aside from categories) into floats
prediction_features = prediction_features.apply(pd.to_numeric, errors='ignore')

# remove columns with NA values
prediction_features = prediction_features.dropna()
# print(prediction_features)

# put labels in separate dataframe
labels_to_predict = prediction_features["categories_en"]
prediction_features.drop('categories_en', axis=1, inplace=True)

# turn labels_to_predict from a string-dataframe into a numbers-dataframe (indicating whether the word 'chocolate' is in categories with 1 or 0)
indeces = []
values = []
for index, value in labels_to_predict.iteritems():
    indeces.append(index)
    if 'chocolate' in value:
        values.append(1.0)
    else:
        values.append(0.0)

values = np.asarray(values)  # turn values into np array
labels_dict = {'is_chocolate' : pd.Series(values, indeces)} 

labels_to_predict = pd.DataFrame(labels_dict)

for index, value in labels_to_predict['is_chocolate'].iteritems():
    pass#print(value)

# TODO: need to split this into 3 sets: training, validation(to tweak), test
X_train, X_test, y_train, y_test = train_test_split(prediction_features, labels_to_predict, random_state=22)

# %%
# build tree (fit) and get cross-val using training data

X_train_len = len(X_train["fat_100g"].values)
y_train_len = len(y_train["is_chocolate"].values)

fat_data = X_train["fat_100g"].values.reshape(X_train_len, 1)
sugars_data = X_train["sugars_100g"].values.reshape(X_train_len, 1)
salt_data = X_train["salt_100g"].values.reshape(X_train_len, 1)
energy_data = X_train["energy_100g"].values.reshape(X_train_len, 1)

# combine training data and flatten label-column to list
train_data = np.hstack([fat_data, sugars_data, salt_data, energy_data])
final_labels_train = np.ravel(y_train)

forest = forest.fit(train_data, final_labels_train)

# determine cross validation score
scores = cross_val_score(forest, train_data, final_labels_train, scoring='accuracy', cv = 5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.98 (+/- 0.01)

# %%
# get f1-score based on test data
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score


X_test_len = len(X_test["fat_100g"].values)

fat_test = X_test["fat_100g"].values.reshape(X_test_len, 1)
sugars_test = X_test["sugars_100g"].values.reshape(X_test_len, 1)
salt_test = X_test["salt_100g"].values.reshape(X_test_len, 1)
energy_test = X_test["energy_100g"].values.reshape(X_test_len, 1)

final_data_test = np.hstack([fat_test, sugars_test, salt_test, energy_test])
final_labels_test = np.ravel(y_test)

y_predicted = forest.predict(final_data_test)
for i in y_predicted:
    pass#print(i)
#y_accurancy = np.mean(final_labels_test == y_predicted) * 100
#print("Accuracy of test data: {0:.1f}%".format(y_accurancy))

# print(fat_test)

recall = recall_score(y_test, y_predicted)
precision = precision_score(y_test, y_predicted)
f_score = f1_score(y_test, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# recall: 0.639705882353
# precision:  0.692307692308
# f1_score:  0.664968152866

# %%
#print(predict_chocolate(food))

cleansed_candies = tagged_candies.apply(pd.to_numeric, errors='ignore')
cleansed_candies = cleansed_candies.dropna(subset=["fat_100g", "sugars_100g", "salt_100g", "energy_100g"])

acc = 0
for i in (predict_chocolate(cleansed_candies)):
    acc += i
    
print("predicts: ", acc)

acc = 0
for index, value in cleansed_candies['categories_en'].iteritems():
    if "Choc" in value:
        acc += 1

print("chcocs: ", acc)

acc = 0
y_predicted = predict_chocolate(cleansed_candies)
for i in (y_predicted):
    if "Choc" in value:
        acc += i
print("true positives: ", acc)
# good scores but poor performance in predicting chocolate; good scores come from high amounts of true negatives.
# Not great tbh fam
# Out:
# removing columns with NaN, might prevent aligning original df with predictions; pls remove NaN columns ahead of time
# predicts:  60.0
# chcocs:  294
# removing columns with NaN, might prevent aligning original df with predictions; pls remove NaN columns ahead of time
# true positives:  60.0

# %%
# print precision, recall and f1_score of sweets-only prediction

y_test_cleansed_candies = cleansed_candies['categories_en'].copy()
for index, value in y_test_cleansed_candies.iteritems():
    if "Choc" in value:
        y_test_cleansed_candies[index] = "1"
    else:
        y_test_cleansed_candies[index] = "0"

        
y_test_cleansed_candies = y_test_cleansed_candies.astype(int).values
        
# problem: yfind out what y_predicted contains
    
recall = recall_score(y_test_cleansed_candies, y_predicted)
precision = precision_score(y_test_cleansed_candies, y_predicted)
f_score = f1_score(y_test_cleansed_candies, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# recall: 0.200680272109
# precision:  0.983333333333
# f1_score:  0.333333333333

# %%
chocs_only = food.dropna(subset=["categories_en"])
chocs_only = chocs_only[chocs_only['categories_en'].str.contains("Choc")]
chocs_only = chocs_only.apply(pd.to_numeric, errors='ignore')
chocs_only = chocs_only.dropna(subset=["fat_100g", "sugars_100g", "salt_100g", "energy_100g"])

trace = go.Scatter(
    x = chocs_only['sugars_100g'],
    y = chocs_only["energy_100g"].astype(float),
    mode = 'markers'
)

layout = go.Layout(
    title= 'Chocolates: sugar to energy',
    xaxis= dict(
        range=[0, 100],
        title="sugar in g / 100g"
    ),
    yaxis=dict(
        #range=[0, 100],
        title="energy in J / 100g"
    )
)

data = [trace]

fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='choc-sugar_energy_ratio_scatter')

# %%
trace = go.Scatter(
    x = chocs_only['fat_100g'],
    y = chocs_only["salt_100g"].astype(float),
    mode = 'markers'
)

layout = go.Layout(
    title= 'Chocolates: fat to salt',
    xaxis= dict(
        range=[0, 100],
        title="fat in g / 100g"
    ),
    yaxis=dict(
        #range=[0, 100],
        title="salt in g / 100g"
    )
)

data = [trace]

fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='choc-fat_salt_ratio_scatter')

# %%
trace = go.Scatter(
    x = food['fat_100g'].astype(float),
    y = food["salt_100g"].astype(float),
    mode = 'markers'
)

layout = go.Layout(
    title= 'Food: fat to salt',
    xaxis= dict(
        range=[0, 100],
        title="fat in g / 100g"
    ),
    yaxis=dict(
        range=[0, 100],
        title="salt in g / 100g"
    )
)

data = [trace]

fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='food-fat_salt_ratio_scatter')

# %%
dark_chocs = chocs_only[chocs_only['categories_en'].str.contains("Dark")]
white_chocs = chocs_only[chocs_only['categories_en'].str.contains("White")]

print(len(dark_chocs))
#print(dark_chocs)

trace1 = go.Scatter(
    x = chocs_only['sugars_100g'],
    y = chocs_only["energy_100g"].astype(float),
    mode = 'markers',
    name = "All Chocolates",
    marker = dict(
        color = 'rgba(255, 182, 193, .9)'
    )
)

trace2 = go.Scatter(
    x = white_chocs['sugars_100g'],
    y = white_chocs["energy_100g"].astype(float),
    mode = 'markers',
    name = "white Chocolates",
    marker = dict(
        #size = 10,
        color = 'rgba(152, 0, 0, .8)'
       # line = dict(
       #     width = 2,
       #     color = 'rgb(0, 0, 0)'
       # )
    )
)

layout = go.Layout(
    title= 'White Chocolates: sugar to energy',
    xaxis= dict(
        range=[0, 100],
        title="sugar in g / 100g"
    ),
    yaxis=dict(
        #range=[0, 100],
        title="energy in J / 100g"
    )
)

data = [trace1, trace2]

fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='white_choc-sugar_energy_ratio_scatter')
# Out:
# 724

# %%
trace1 = go.Scatter(
    x = chocs_only['sugars_100g'],
    y = chocs_only["energy_100g"].astype(float),
    mode = 'markers',
    name = "All Chocolates",
    marker = dict(
        color = 'rgba(255, 182, 193, .9)'
    )
)

trace2 = go.Scatter(
    x = dark_chocs['sugars_100g'],
    y = dark_chocs["energy_100g"].astype(float),
    mode = 'markers',
    name = "Dark Chocolates",
    marker = dict(
        #size = 10,
        color = 'rgba(152, 0, 0, .8)'
       # line = dict(
       #     width = 2,
       #     color = 'rgb(0, 0, 0)'
       # )
    )
)

layout = go.Layout(
    title= 'Dark Chocolates: sugar to energy',
    xaxis= dict(
        range=[0, 100],
        title="sugar in g / 100g"
    ),
    yaxis=dict(
        #range=[0, 100],
        title="energy in J / 100g"
    )
)

data = [trace1, trace2]

fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='dark_choc-sugar_energy_ratio_scatter')

# %%
# predict dark chocolate
dark_predcols = ["sugars_100g", "energy_100g", "salt_100g", "fat_100g", "proteins_100g", "carbohydrates_100g"]
dark_choc_forest, dark_choc_y_test, dark_choc_X_test = train_forest(dark_predcols, "Dark choco")

y_predicted = predict(dark_choc_forest, dark_choc_X_test, dark_predcols)

recall = recall_score(dark_choc_y_test, y_predicted)
precision = precision_score(dark_choc_y_test, y_predicted)
f_score = f1_score(dark_choc_y_test, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# Accuracy: 0.99 (+/- 0.00)
# recall: 0.752747252747
# precision:  0.796511627907
# f1_score:  0.774011299435

# %%
# predict white chocolate
white_predcols = ["sugars_100g", "energy_100g", "salt_100g", "fat_100g", "proteins_100g", "carbohydrates_100g"]
white_choc_forest, white_choc_y_test, white_choc_X_test = train_forest(white_predcols, "White choco")

y_predicted = predict(white_choc_forest, white_choc_X_test, white_predcols)

recall = recall_score(white_choc_y_test, y_predicted)
precision = precision_score(white_choc_y_test, y_predicted)
f_score = f1_score(white_choc_y_test, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# Accuracy: 1.00 (+/- 0.00)
# recall: 0.133333333333
# precision:  1.0
# f1_score:  0.235294117647

# %%
# predict milk chocolate
milk_predcols = ["sugars_100g", "salt_100g", "fat_100g", "proteins_100g"]
milk_choc_forest, milk_choc_y_test, milk_choc_X_test = train_forest(milk_predcols, "Milk choco", forest_count = 500)

y_predicted = predict(milk_choc_forest, milk_choc_X_test, milk_predcols)

recall = recall_score(milk_choc_y_test, y_predicted)
precision = precision_score(milk_choc_y_test, y_predicted)
f_score = f1_score(milk_choc_y_test, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# Accuracy: 0.99 (+/- 0.00)
# recall: 0.503546099291
# precision:  0.628318584071
# f1_score:  0.55905511811

# %%
predict_chocolate_unified([milk_choc_forest], clean_food, [milk_predcols])
# Out:
# [code                                        0009542018054
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2400
# fat_100g                                               40
# sugars_100g                                            50
# proteins_100g                                           5
# salt_100g                                           0.222
# Name: 191, dtype: object, code             0034000123803
# categories_en          Spreads
# energy_100g               2260
# fat_100g                  32.4
# sugars_100g               51.4
# proteins_100g             8.11
# salt_100g                0.343
# Name: 1257, dtype: object, code                                                 0034000171156
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2090
# fat_100g                                                      31.6
# sugars_100g                                                     50
# proteins_100g                                                 10.5
# salt_100g                                                    0.167
# Name: 1260, dtype: object, code                                        0034000290352
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2040
# fat_100g                                             30.2
# sugars_100g                                          55.8
# proteins_100g                                        6.98
# salt_100g                                           0.207
# Name: 1264, dtype: object, code                                        0034000441037
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2299
# fat_100g                                             31.2
# sugars_100g                                          50.2
# proteins_100g                                        10.2
# salt_100g                                           0.762
# Name: 1270, dtype: object, code                                        0037466083247
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2290
# fat_100g                                             35.7
# sugars_100g                                          45.2
# proteins_100g                                        9.52
# salt_100g                                           0.302
# Name: 1373, dtype: object, code                                                 0052302222222
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2400
# fat_100g                                                        40
# sugars_100g                                                   42.5
# proteins_100g                                                   10
# salt_100g                                                    0.191
# Name: 2171, dtype: object, code                                                 0067300860758
# categories_en    Sugary snacks,Confectioneries,Candies,Bars,Cho...
# energy_100g                                                   2200
# fat_100g                                                      27.5
# sugars_100g                                                     60
# proteins_100g                                                    5
# salt_100g                                                    0.191
# Name: 2797, dtype: object, code                                                 0070221011116
# categories_en    Sugary snacks,Confectioneries,Candies,Chocolat...
# energy_100g                                                   2280
# fat_100g                                                      30.3
# sugars_100g                                                   60.6
# proteins_100g                                                 6.06
# salt_100g                                                    0.154
# Name: 2990, dtype: object, code                                                 0070221035020
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2200
# fat_100g                                                        30
# sugars_100g                                                     60
# proteins_100g                                                    5
# salt_100g                                                    0.159
# Name: 2991, dtype: object, code                                        0072799035570
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2310
# fat_100g                                             36.8
# sugars_100g                                          47.4
# proteins_100g                                        7.89
# salt_100g                                           0.134
# Name: 3248, dtype: object, code                                                 0096619376056
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2230
# fat_100g                                                        40
# sugars_100g                                                   33.3
# proteins_100g                                                   10
# salt_100g                                                    0.127
# Name: 4151, dtype: object, code                                             01888584
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2145
# fat_100g                                             26.5
# sugars_100g                                          60.2
# proteins_100g                                         5.8
# salt_100g                                         0.28956
# Name: 4891, dtype: object, code                                             03424005
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2040
# fat_100g                                             30.2
# sugars_100g                                          55.8
# proteins_100g                                        6.98
# salt_100g                                           0.207
# Name: 5662, dtype: object, code                                             03444009
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2090
# fat_100g                                               31
# sugars_100g                                            50
# proteins_100g                                        11.9
# salt_100g                                           0.907
# Name: 5669, dtype: object, code                                        0818192010314
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2240
# fat_100g                                             32.6
# sugars_100g                                          51.2
# proteins_100g                                        6.98
# salt_100g                                           0.266
# Name: 6731, dtype: object, code                                                      08772350
# categories_en    Sugary snacks,Confectioneries,Candies,Chocolat...
# energy_100g                                                   2310
# fat_100g                                                      34.5
# sugars_100g                                                   47.5
# proteins_100g                                                  8.8
# salt_100g                                                 0.249936
# Name: 7015, dtype: object, code                                        0894162002138
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2340
# fat_100g                                               36
# sugars_100g                                            52
# proteins_100g                                           6
# salt_100g                                           0.152
# Name: 7072, dtype: object, code                                        0894162002152
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2340
# fat_100g                                               38
# sugars_100g                                            46
# proteins_100g                                           8
# salt_100g                                           0.127
# Name: 7074, dtype: object, code                                              11888560
# categories_en    Sugary snacks,Chocolates,White chocolates
# energy_100g                                           2200
# fat_100g                                              27.7
# sugars_100g                                           63.1
# proteins_100g                                          5.6
# salt_100g                                         0.189992
# Name: 7403, dtype: object, code                                        1402939250003
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2167
# fat_100g                                               27
# sugars_100g                                            60
# proteins_100g                                         5.8
# salt_100g                                            0.17
# Name: 7567, dtype: object, code                                                      20005771
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2397
# fat_100g                                                      40.1
# sugars_100g                                                   40.2
# proteins_100g                                                  8.7
# salt_100g                                                   0.2032
# Name: 9262, dtype: object, code                                                      20005795
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2473
# fat_100g                                                      41.7
# sugars_100g                                                   38.7
# proteins_100g                                                  9.7
# salt_100g                                                   0.1778
# Name: 9264, dtype: object, code                                             20005818
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2487
# fat_100g                                             43.4
# sugars_100g                                          37.9
# proteins_100g                                         8.3
# salt_100g                                          0.1778
# Name: 9266, dtype: object, code                                             20005825
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2216
# fat_100g                                             29.6
# sugars_100g                                          57.6
# proteins_100g                                         6.2
# salt_100g                                           0.254
# Name: 9267, dtype: object, code                                                      20030285
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2364
# fat_100g                                                      36.5
# sugars_100g                                                   51.7
# proteins_100g                                                  6.2
# salt_100g                                                    0.254
# Name: 9521, dtype: object, code                                                      20047009
# categories_en    Sugary snacks,Chocolates,Christmas foods and d...
# energy_100g                                                   2307
# fat_100g                                                      32.9
# sugars_100g                                                   56.2
# proteins_100g                                                  6.5
# salt_100g                                                      0.2
# Name: 9640, dtype: object, code                                                      20080181
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2209
# fat_100g                                                      32.9
# sugars_100g                                                   47.6
# proteins_100g                                                  6.5
# salt_100g                                                   0.1778
# Name: 9813, dtype: object, code                                             20088057
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2328
# fat_100g                                               36
# sugars_100g                                            49
# proteins_100g                                         7.5
# salt_100g                                            0.38
# Name: 9871, dtype: object, code                                                      20091330
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2365
# fat_100g                                                      36.5
# sugars_100g                                                   51.8
# proteins_100g                                                  6.2
# salt_100g                                                    0.254
# Name: 9878, dtype: object, code                                             20113520
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2344
# fat_100g                                               36
# sugars_100g                                            50
# proteins_100g                                         7.2
# salt_100g                                          0.1524
# Name: 10009, dtype: object, code                                             20131548
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2394
# fat_100g                                             37.6
# sugars_100g                                          50.2
# proteins_100g                                         6.2
# salt_100g                                           0.254
# Name: 10108, dtype: object, code                                             20136321
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2278
# fat_100g                                             32.7
# sugars_100g                                          51.5
# proteins_100g                                           7
# salt_100g                                          0.2032
# Name: 10127, dtype: object, code                                                      20154349
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2357
# fat_100g                                                      36.5
# sugars_100g                                                   47.6
# proteins_100g                                                  7.5
# salt_100g                                                    0.254
# Name: 10223, dtype: object, code                                             20303242
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2358
# fat_100g                                             39.2
# sugars_100g                                          45.5
# proteins_100g                                         6.9
# salt_100g                                           0.254
# Name: 10897, dtype: object, code                                                      20418755
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2412
# fat_100g                                                      39.2
# sugars_100g                                                   48.2
# proteins_100g                                                  7.4
# salt_100g                                                   0.2032
# Name: 11357, dtype: object, code                                             20573126
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                           471
# fat_100g                                             5.51
# sugars_100g                                          10.4
# proteins_100g                                         3.5
# salt_100g                                          0.0988
# Name: 11959, dtype: object, code                                                      20638269
# categories_en    Sugary snacks,Chocolates,Chocolate eggs,Easter...
# energy_100g                                                   2355
# fat_100g                                                        36
# sugars_100g                                                     52
# proteins_100g                                                  6.3
# salt_100g                                                      0.2
# Name: 12197, dtype: object, code                                                 2092933299994
# categories_en    Sugary snacks,Confectioneries,Candies,Chocolat...
# energy_100g                                                   2148
# fat_100g                                                      25.6
# sugars_100g                                                   62.4
# proteins_100g                                                  5.5
# salt_100g                                                      0.1
# Name: 12552, dtype: object, code                                             23281028
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2404
# fat_100g                                             40.9
# sugars_100g                                          37.9
# proteins_100g                                        10.1
# salt_100g                                            0.15
# Name: 13579, dtype: object, code                                                      26034744
# categories_en    Sugary snacks,Confectioneries,Bars,Chocolate b...
# energy_100g                                                   2200
# fat_100g                                                      30.2
# sugars_100g                                                   47.7
# proteins_100g                                                  8.3
# salt_100g                                                   0.1778
# Name: 14643, dtype: object, code                                                      26038377
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2343
# fat_100g                                                        36
# sugars_100g                                                     51
# proteins_100g                                                  5.4
# salt_100g                                                     0.15
# Name: 14713, dtype: object, code                                             26039541
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2267
# fat_100g                                               34
# sugars_100g                                            51
# proteins_100g                                         7.1
# salt_100g                                          0.2286
# Name: 14726, dtype: object, code                                                      26039572
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2281
# fat_100g                                                      31.9
# sugars_100g                                                   54.2
# proteins_100g                                                  8.1
# salt_100g                                                   0.2032
# Name: 14727, dtype: object, code                                             26039596
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2433
# fat_100g                                             39.8
# sugars_100g                                          40.5
# proteins_100g                                        10.2
# salt_100g                                        0.169926
# Name: 14729, dtype: object, code                                             26040042
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2138
# fat_100g                                               26
# sugars_100g                                            50
# proteins_100g                                         8.2
# salt_100g                                            0.55
# Name: 14740, dtype: object, code                                             26046631
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          1953
# fat_100g                                               24
# sugars_100g                                            56
# proteins_100g                                         5.9
# salt_100g                                          0.4572
# Name: 14840, dtype: object, code                                                      26051147
# categories_en    Sugary snacks,Biscuits and cakes,Confectioneri...
# energy_100g                                                   2292
# fat_100g                                                      32.5
# sugars_100g                                                   47.7
# proteins_100g                                                  7.6
# salt_100g                                                     0.15
# Name: 14873, dtype: object, code                                             26061641
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2210
# fat_100g                                               28
# sugars_100g                                            62
# proteins_100g                                           5
# salt_100g                                            0.13
# Name: 14926, dtype: object, code                                                      26216256
# categories_en    Sugary snacks,Chocolates,Easter-moulded-chocolate
# energy_100g                                                   2300
# fat_100g                                                      34.3
# sugars_100g                                                   51.1
# proteins_100g                                                  7.1
# salt_100g                                                   0.2032
# Name: 15350, dtype: object, code                                             27020777
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2120
# fat_100g                                               30
# sugars_100g                                            51
# proteins_100g                                         7.5
# salt_100g                                            0.28
# Name: 15552, dtype: object, code                                                      29024742
# categories_en    Sugary snacks,Chocolates,Chocolate molds,Milk ...
# energy_100g                                                   2267
# fat_100g                                                        32
# sugars_100g                                                     54
# proteins_100g                                                  6.4
# salt_100g                                                     0.17
# Name: 15951, dtype: object, code                             29039678
# categories_en    Sugary snacks,Chocolates
# energy_100g                          2358
# fat_100g                             37.2
# sugars_100g                          44.7
# proteins_100g                         9.3
# salt_100g                            0.23
# Name: 16001, dtype: object, code                                                      29040407
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2420
# fat_100g                                                      38.8
# sugars_100g                                                   46.9
# proteins_100g                                                  8.5
# salt_100g                                                    0.254
# Name: 16008, dtype: object, code                                                      30076600
# categories_en    Sugary snacks,Chocolates,Chocolate molds,Milk ...
# energy_100g                                                   2220
# fat_100g                                                      29.5
# sugars_100g                                                     58
# proteins_100g                                                  6.4
# salt_100g                                                     0.43
# Name: 16279, dtype: object, code                                        3017620713729
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2360
# fat_100g                                               35
# sugars_100g                                          53.3
# proteins_100g                                         8.7
# salt_100g                                           0.313
# Name: 16537, dtype: object, code                                        3017620716362
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2360
# fat_100g                                               35
# sugars_100g                                          53.3
# proteins_100g                                         8.7
# salt_100g                                           0.313
# Name: 16538, dtype: object, code                                        3017627101604
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2360
# fat_100g                                               35
# sugars_100g                                          53.3
# proteins_100g                                         8.7
# salt_100g                                         0.31242
# Name: 16554, dtype: object, code                                        3017627132509
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2360
# fat_100g                                               35
# sugars_100g                                          53.3
# proteins_100g                                         8.7
# salt_100g                                           0.313
# Name: 16555, dtype: object, code                                                 3017760002073
# categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# energy_100g                                                   2070
# fat_100g                                                      23.2
# sugars_100g                                                   39.2
# proteins_100g                                                 6.72
# salt_100g                                                    0.488
# Name: 16565, dtype: object, code                                                 3017760329798
# categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# energy_100g                                                   2175
# fat_100g                                                        29
# sugars_100g                                                     38
# proteins_100g                                                  5.4
# salt_100g                                                   0.3048
# Name: 16601, dtype: object, code                                                 3017760648295
# categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# energy_100g                                                   2050
# fat_100g                                                        22
# sugars_100g                                                     30
# proteins_100g                                                  6.8
# salt_100g                                                   0.7366
# Name: 16665, dtype: object, code                                                 3017760790895
# categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# energy_100g                                                   1980
# fat_100g                                                        19
# sugars_100g                                                     37
# proteins_100g                                                  6.5
# salt_100g                                                      0.7
# Name: 16696, dtype: object, code                                                 3017760826174
# categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# energy_100g                                                   2080
# fat_100g                                                        24
# sugars_100g                                                     30
# proteins_100g                                                  6.6
# salt_100g                                                   1.1938
# Name: 16705, dtype: object, code                                                 3045140015832
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2390
# fat_100g                                                        39
# sugars_100g                                                     42
# proteins_100g                                                  9.3
# salt_100g                                                   0.2794
# Name: 19382, dtype: object, code                                                 3045140105106
# categories_en    Desserts,Sugary snacks,Confectioneries,Chocola...
# energy_100g                                                   2210
# fat_100g                                                      29.5
# sugars_100g                                                   57.5
# proteins_100g                                                  6.6
# salt_100g                                                   0.4318
# Name: 19384, dtype: object, code                                        3045140105502
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2220
# fat_100g                                             29.5
# sugars_100g                                            58
# proteins_100g                                         6.4
# salt_100g                                            0.43
# Name: 19385, dtype: object, code                                        3045140105557
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2220
# fat_100g                                             29.5
# sugars_100g                                            58
# proteins_100g                                         6.4
# salt_100g                                            0.43
# Name: 19386, dtype: object, code                                                 3045140118106
# categories_en    Desserts,Sugary snacks,Chocolates,Milk chocola...
# energy_100g                                                   2325
# fat_100g                                                      36.5
# sugars_100g                                                     46
# proteins_100g                                                  8.6
# salt_100g                                                   0.3556
# Name: 19387, dtype: object, code                                                 3045140118502
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2320
# fat_100g                                                      35.5
# sugars_100g                                                     47
# proteins_100g                                                  8.1
# salt_100g                                                     0.35
# Name: 19388, dtype: object, code                                                 3045140118526
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2315
# fat_100g                                                        36
# sugars_100g                                                     47
# proteins_100g                                                  8.4
# salt_100g                                                   0.3556
# Name: 19389, dtype: object, code                                        3045140280902
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2080
# fat_100g                                               26
# sugars_100g                                            56
# proteins_100g                                           6
# salt_100g                                            0.33
# Name: 19392, dtype: object, code                                                 3046920005739
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2210
# fat_100g                                                        29
# sugars_100g                                                     56
# proteins_100g                                                  5.4
# salt_100g                                                      0.2
# Name: 19563, dtype: object, code                                                 3046920006804
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2264
# fat_100g                                                        32
# sugars_100g                                                     53
# proteins_100g                                                  6.6
# salt_100g                                                      0.2
# Name: 19568, dtype: object, code                                        3046920007405
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2193
# fat_100g                                               29
# sugars_100g                                            55
# proteins_100g                                         5.2
# salt_100g                                            0.19
# Name: 19573, dtype: object, code                                                 3046920007443
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2220
# fat_100g                                                        31
# sugars_100g                                                     51
# proteins_100g                                                    6
# salt_100g                                                     0.18
# Name: 19575, dtype: object, code                                                 3046920007450
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2295
# fat_100g                                                        33
# sugars_100g                                                     54
# proteins_100g                                                  5.3
# salt_100g                                                     0.33
# Name: 19576, dtype: object, code                                                 3046920007702
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2355
# fat_100g                                                        36
# sugars_100g                                                     53
# proteins_100g                                                  6.1
# salt_100g                                                      0.2
# Name: 19579, dtype: object, code                                        3046920007733
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2435
# fat_100g                                               40
# sugars_100g                                            46
# proteins_100g                                         5.4
# salt_100g                                            0.21
# Name: 19582, dtype: object, code                                        3046920007740
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2290
# fat_100g                                               33
# sugars_100g                                            54
# proteins_100g                                         6.4
# salt_100g                                            0.18
# Name: 19583, dtype: object, code                                                 3046920009980
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                    605
# fat_100g                                                        45
# sugars_100g                                                     44
# proteins_100g                                                  5.2
# salt_100g                                                      0.2
# Name: 19591, dtype: object, code                                        3046920010283
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2387
# fat_100g                                               37
# sugars_100g                                            50
# proteins_100g                                         6.4
# salt_100g                                          0.2794
# Name: 19594, dtype: object, code                                                 3046920011501
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2294
# fat_100g                                                        33
# sugars_100g                                                     56
# proteins_100g                                                  5.5
# salt_100g                                                     0.31
# Name: 19608, dtype: object, code                                                 3046920012010
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2276
# fat_100g                                                        32
# sugars_100g                                                     55
# proteins_100g                                                    7
# salt_100g                                                     0.25
# Name: 19609, dtype: object, code                                                 3046920012690
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2158
# fat_100g                                                        28
# sugars_100g                                                     52
# proteins_100g                                                    7
# salt_100g                                                     0.89
# Name: 19610, dtype: object, code                                                 3046920012775
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2159
# fat_100g                                                        28
# sugars_100g                                                     52
# proteins_100g                                                    7
# salt_100g                                                     0.79
# Name: 19611, dtype: object, code                                                 3046920014038
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2399
# fat_100g                                                        38
# sugars_100g                                                     52
# proteins_100g                                                  5.5
# salt_100g                                                     0.22
# Name: 19615, dtype: object, code                                                 3046920019798
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2269
# fat_100g                                                        33
# sugars_100g                                                     53
# proteins_100g                                                  6.8
# salt_100g                                                     0.14
# Name: 19625, dtype: object, code                                                 3046920020916
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2335
# fat_100g                                                        34
# sugars_100g                                                     56
# proteins_100g                                                    4
# salt_100g                                                     0.15
# Name: 19631, dtype: object, code                                        3046920020978
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2328
# fat_100g                                               34
# sugars_100g                                            56
# proteins_100g                                           4
# salt_100g                                            0.15
# Name: 19634, dtype: object, code                                                 3046920021425
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2364
# fat_100g                                                        37
# sugars_100g                                                     47
# proteins_100g                                                    8
# salt_100g                                                     0.13
# Name: 19638, dtype: object, code                                                 3046920023009
# categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
# energy_100g                                                   2325
# fat_100g                                                        35
# sugars_100g                                                     48
# proteins_100g                                                  6.4
# salt_100g                                                     0.11
# Name: 19645, dtype: object, code                                        3046920026833
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2276
# fat_100g                                               32
# sugars_100g                                            55
# proteins_100g                                           7
# salt_100g                                            0.25
# Name: 19651, dtype: object, code                                                 3046920041911
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2531
# fat_100g                                                        45
# sugars_100g                                                     44
# proteins_100g                                                  5.2
# salt_100g                                                      0.2
# Name: 19690, dtype: object, code                                                 3046920042642
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2286
# fat_100g                                                        33
# sugars_100g                                                     53
# proteins_100g                                                  5.7
# salt_100g                                                      0.2
# Name: 19691, dtype: object, code                                        3046920042758
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2524
# fat_100g                                               45
# sugars_100g                                            43
# proteins_100g                                         5.1
# salt_100g                                            0.16
# Name: 19692, dtype: object, code                                        3046920042802
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2524
# fat_100g                                               45
# sugars_100g                                            43
# proteins_100g                                         5.1
# salt_100g                                            0.16
# Name: 19694, dtype: object, code                                        3046920042826
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2531
# fat_100g                                               45
# sugars_100g                                            44
# proteins_100g                                         5.2
# salt_100g                                             0.2
# Name: 19695, dtype: object, code                                                 3046920043380
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2164
# fat_100g                                                        30
# sugars_100g                                                     54
# proteins_100g                                                  5.6
# salt_100g                                                     0.21
# Name: 19698, dtype: object, code                                        3046920045711
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2264
# fat_100g                                               32
# sugars_100g                                            53
# proteins_100g                                         6.6
# salt_100g                                             0.2
# Name: 19714, dtype: object, code                        3046920045766
# categories_en    Sugary snacks,Chocolates
# energy_100g                          2290
# fat_100g                               33
# sugars_100g                            54
# proteins_100g                         6.4
# salt_100g                            0.18
# Name: 19716, dtype: object, code                                                 3046920045773
# categories_en    Sugary snacks,Chocolates,Milk chocolates,fr:Ch...
# energy_100g                                                   2399
# fat_100g                                                        38
# sugars_100g                                                     51
# proteins_100g                                                  5.5
# salt_100g                                                     0.21
# Name: 19717, dtype: object, code                                        3046920047302
# categories_en    Sugary snacks,Chocolates,Milk chocolates
# energy_100g                                          2193
# fat_100g                                               29
# sugars_100g                                            55
# proteins_100g                                         5.2
# salt_100g                                            0.19
# Name: 19721, dtype: object, code                                                 3046920047340
# categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
# energy_100g                                                   2393
# fat_100g                                                        38
# ...
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2388
#  fat_100g                                               37
#  sugars_100g                                            53
#  proteins_100g                                         5.2
#  salt_100g                                            0.38
#  Name: 92027, dtype: object, code                                        7622400893124
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2406
#  fat_100g                                             38.5
#  sugars_100g                                            52
#  proteins_100g                                         5.3
#  salt_100g                                            0.43
#  Name: 92028, dtype: object, code                                        8000300264388
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2151
#  fat_100g                                             25.9
#  sugars_100g                                          51.5
#  proteins_100g                                         6.9
#  salt_100g                                         0.29972
#  Name: 92900, dtype: object, code                                        8000300312102
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2151
#  fat_100g                                             25.9
#  sugars_100g                                          51.5
#  proteins_100g                                         6.9
#  salt_100g                                         0.29972
#  Name: 92913, dtype: object, code                                        8000500111581
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2360
#  fat_100g                                               35
#  sugars_100g                                          53.3
#  proteins_100g                                         8.7
#  salt_100g                                         0.31242
#  Name: 93035, dtype: object, code                                                 8000500141601
#  categories_en    Sugary snacks,Chocolates,Milk chocolates,Easte...
#  energy_100g                                                   2352
#  fat_100g                                                      34.8
#  sugars_100g                                                   53.2
#  proteins_100g                                                  8.7
#  salt_100g                                                    0.123
#  Name: 93052, dtype: object, code                                                 8000500147672
#  categories_en    Sugary snacks,Confectioneries,Chocolates,Bars,...
#  energy_100g                                                   2630
#  fat_100g                                                        35
#  sugars_100g                                                   53.3
#  proteins_100g                                                  8.7
#  salt_100g                                                    0.313
#  Name: 93059, dtype: object, code                                                 8000500160749
#  categories_en    Sugary snacks,Confectioneries,Chocolates,Milk ...
#  energy_100g                                                   2318
#  fat_100g                                                        33
#  sugars_100g                                                   32.8
#  proteins_100g                                                  7.5
#  salt_100g                                                    0.308
#  Name: 93066, dtype: object, code                                                 8000500182512
#  categories_en    Sugary snacks,Chocolates,Chocolate molds,Milk ...
#  energy_100g                                                   2413
#  fat_100g                                                      36.2
#  sugars_100g                                                   53.6
#  proteins_100g                                                  8.8
#  salt_100g                                                    0.305
#  Name: 93094, dtype: object, code                                        8000500188620
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2360
#  fat_100g                                               35
#  sugars_100g                                          53.3
#  proteins_100g                                         8.7
#  salt_100g                                           0.313
#  Name: 93100, dtype: object, code                        8000500189122
#  categories_en    Sugary snacks,Chocolates
#  energy_100g                          2368
#  fat_100g                               35
#  sugars_100g                          53.3
#  proteins_100g                         8.7
#  salt_100g                           0.313
#  Name: 93101, dtype: object, code                                                 8000500222706
#  categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
#  energy_100g                                                   2302
#  fat_100g                                                      34.2
#  sugars_100g                                                   52.1
#  proteins_100g                                                  8.1
#  salt_100g                                                    0.323
#  Name: 93124, dtype: object, code                                                 8002352207054
#  categories_en    Breakfasts,Spreads,Sweet spreads,fr:Pâtes à ta...
#  energy_100g                                                   2171
#  fat_100g                                                      33.9
#  sugars_100g                                                   49.5
#  proteins_100g                                                  9.3
#  salt_100g                                                      0.1
#  Name: 93725, dtype: object, code                                                 8003340090177
#  categories_en    Sugary snacks,Confectioneries,Candies,Chocolat...
#  energy_100g                                                   2589
#  fat_100g                                                        47
#  sugars_100g                                                     43
#  proteins_100g                                                  4.9
#  salt_100g                                                     0.23
#  Name: 93972, dtype: object, code                                           8003340090535
#  categories_en    Sugary snacks,Chocolates,Chocolate truffles
#  energy_100g                                             2587
#  fat_100g                                                  47
#  sugars_100g                                               43
#  proteins_100g                                            4.9
#  salt_100g                                               0.23
#  Name: 93976, dtype: object, code                                                 8004735031089
#  categories_en    Sugary snacks,Chocolates,Milk chocolates,Choco...
#  energy_100g                                                   2280
#  fat_100g                                                      32.5
#  sugars_100g                                                   56.2
#  proteins_100g                                                  5.6
#  salt_100g                                                     0.08
#  Name: 94151, dtype: object, code                                                 8008698004548
#  categories_en    Sugary snacks,Biscuits and cakes,Biscuits,Choc...
#  energy_100g                                                   2144
#  fat_100g                                                        24
#  sugars_100g                                                     34
#  proteins_100g                                                  6.7
#  salt_100g                                                     0.75
#  Name: 94593, dtype: object, code                                                      80177616
#  categories_en    Sugary snacks,Confectioneries,Chocolates,Bars,...
#  energy_100g                                                   2360
#  fat_100g                                                        35
#  sugars_100g                                                   53.3
#  proteins_100g                                                  8.7
#  salt_100g                                                    0.313
#  Name: 95054, dtype: object, code                                        8056450920117
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2358
#  fat_100g                                             37.2
#  sugars_100g                                          45.1
#  proteins_100g                                         9.9
#  salt_100g                                               0
#  Name: 95648, dtype: object, code                                        8056450920162
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2358
#  fat_100g                                             37.2
#  sugars_100g                                          45.1
#  proteins_100g                                         9.9
#  salt_100g                                               0
#  Name: 95649, dtype: object, code                                                 8410100098531
#  categories_en    Sugary snacks,Confectioneries,Candies,Chocolat...
#  energy_100g                                                   2349
#  fat_100g                                                        36
#  sugars_100g                                                   49.3
#  proteins_100g                                                  7.4
#  salt_100g                                                   0.2032
#  Name: 96491, dtype: object, code                                        8410109000061
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2242
#  fat_100g                                             31.5
#  sugars_100g                                          53.5
#  proteins_100g                                         7.3
#  salt_100g                                            0.35
#  Name: 96497, dtype: object, code                                        8410109050974
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2150
#  fat_100g                                             30.3
#  sugars_100g                                          51.5
#  proteins_100g                                        6.06
#  salt_100g                                           0.346
#  Name: 96514, dtype: object, code                                        8410510010093
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2312
#  fat_100g                                               34
#  sugars_100g                                            54
#  proteins_100g                                         5.5
#  salt_100g                                           0.254
#  Name: 96934, dtype: object, code                                                 8410740904278
#  categories_en    Breakfasts,Spreads,Sweet spreads,fr:Pâtes à ta...
#  energy_100g                                                   2220
#  fat_100g                                                        31
#  sugars_100g                                                     55
#  proteins_100g                                                    6
#  salt_100g                                                      0.2
#  Name: 97046, dtype: object, code                                                 8436549480911
#  categories_en    Sugary snacks,Chocolates,Christmas foods and d...
#  energy_100g                                                   2200
#  fat_100g                                                      28.6
#  sugars_100g                                                   58.3
#  proteins_100g                                                 5.41
#  salt_100g                                                     0.15
#  Name: 99194, dtype: object, code                                        8480017347237
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2124
#  fat_100g                                               32
#  sugars_100g                                            46
#  proteins_100g                                           8
#  salt_100g                                          0.2794
#  Name: 100554, dtype: object, code                                                 8480017627704
#  categories_en    Breakfasts,Spreads,Sweet spreads,fr:Pâtes à ta...
#  energy_100g                                                   2240
#  fat_100g                                                      31.6
#  sugars_100g                                                   52.8
#  proteins_100g                                                  5.9
#  salt_100g                                                   0.1778
#  Name: 100697, dtype: object, code                                        8480017828675
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2308
#  fat_100g                                               36
#  sugars_100g                                            47
#  proteins_100g                                           8
#  salt_100g                                             0.3
#  Name: 100755, dtype: object, code                                        8690504022725
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2457
#  fat_100g                                             37.4
#  sugars_100g                                          37.3
#  proteins_100g                                         9.4
#  salt_100g                                            0.09
#  Name: 101087, dtype: object, code                                        8690504022732
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2371
#  fat_100g                                             33.3
#  sugars_100g                                          38.7
#  proteins_100g                                        10.5
#  salt_100g                                             0.9
#  Name: 101088, dtype: object, code             8710573723658
#  categories_en          Spreads
#  energy_100g               2341
#  fat_100g                    36
#  sugars_100g                 54
#  proteins_100g                5
#  salt_100g                 0.46
#  Name: 101505, dtype: object, code                                        9002859087431
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2231
#  fat_100g                                             30.6
#  sugars_100g                                          55.9
#  proteins_100g                                         6.2
#  salt_100g                                             0.2
#  Name: 104370, dtype: object, code                                             90457388
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2400
#  fat_100g                                             42.5
#  sugars_100g                                          37.5
#  proteins_100g                                         7.5
#  salt_100g                                           0.191
#  Name: 104596, dtype: object, code                                        9403142000890
#  categories_en    Sugary snacks,Chocolates,Milk chocolates
#  energy_100g                                          2450
#  fat_100g                                             40.9
#  sugars_100g                                          39.5
#  proteins_100g                                           9
#  salt_100g                                         0.15494
#  Name: 106161, dtype: object]

# %%
#plot_attributes("White choco", "White Chocolate")
#plot_attributes("Milk choco", "Milk Chocolate")
#plot_attributes("Dark choco", "Dark Chocolate")
#plot_attributes("", "All Foods", use_only_chocs=False)

# %%
"""
Chocolate predictor:

all food:
recall: 0.639705882353
precision:  0.692307692308
f1_score:  0.664968152866
    
sweets:
recall: 0.200680272109
precision:  0.983333333333
f1_score:  0.333333333333"""

"""
Dark Choc sugar/energy:

recall: 0.489010989011
precision:  0.585526315789
f1_score:  0.532934131737

sugar/energy/salt/fat:

recall: 0.678362573099
precision:  0.738853503185
f1_score:  0.707317073171


-> all worse if we remove salt
-> precision up, rest worse if we add sodium or remove fat

White Choc all-the-things:
recall: 0.133333333333
precision:  1.0
f1_score:  0.235294117647

Milk Choc all but carbohydrates with 500 trees instead of 100:  <BEST f1 MILK>
recall: 0.486842105263
precision:  0.660714285714
f1_score:  0.560606060606

Milk Choc all but carbohydrates & energy with 500 trees instead of 100:  <SIDEGRADE>
recall: 0.503546099291
precision:  0.628318584071
f1_score:  0.55905511811


"""
# Out:
# '\nDark Choc sugar/energy:\n\nrecall: 0.489010989011\nprecision:  0.585526315789\nf1_score:  0.532934131737\n\nsugar/energy/salt/fat:\n\nrecall: 0.678362573099\nprecision:  0.738853503185\nf1_score:  0.707317073171\n\n\n-> all worse if we remove salt\n-> precision up, rest worse if we add sodium or remove fat\n\nWhite Choc all-the-things:\nrecall: 0.133333333333\nprecision:  1.0\nf1_score:  0.235294117647\n\nMilk Choc all but carbohydrates with 500 trees instead of 100:  <BEST f1 MILK>\nrecall: 0.486842105263\nprecision:  0.660714285714\nf1_score:  0.560606060606\n\nMilk Choc all but carbohydrates & energy with 500 trees instead of 100:  <SIDEGRADE>\nrecall: 0.503546099291\nprecision:  0.628318584071\nf1_score:  0.55905511811\n\n\n'

# %%
mult_whites = clean_food.copy()

counter = 0
for index, row in mult_whites.iterrows():
    if "White choco" in row['categories_en']:
        counter += 1
print("pre: ", counter)
# create a df that contains all food but every time there's a white chocolate it is added 20 more times

white_choc_templist = []
for index, row in mult_whites.iterrows():
    if "White choco" in row['categories_en']:
        white_choc_templist.extend([row for i in range(20)])

for i in white_choc_templist:
    i["code"] = int(i["code"]) + 1000
        
mult_whites = mult_whites.append(white_choc_templist, ignore_index=True) # could multiply white_choc_templist here instead of earlier as well

counter = 0
for index, row in mult_whites.iterrows():
    if "White choco" in row['categories_en']:
        counter += 1
print("post: ", counter)
# Out:
# pre:  75
# post:  1575

# %%
white_choc_forest, white_choc_y_test, white_choc_X_test = train_forest(white_predcols, "White choco", forest_count = 100, custom_df = mult_whites)

y_predicted = predict(white_choc_forest, white_choc_X_test, white_predcols)

recall = recall_score(white_choc_y_test, y_predicted)
precision = precision_score(white_choc_y_test, y_predicted)
f_score = f1_score(white_choc_y_test, y_predicted)

print("recall:" , recall)
print("precision: ", precision)
print("f1_score: ", f_score)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'carbohydrates_100g'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-c3a3d8217cfb> in <module>()
# ----> 1 white_choc_forest, white_choc_y_test, white_choc_X_test = train_forest(white_predcols, "White choco", forest_count = 100, custom_df = mult_whites)
#       2
#       3 y_predicted = predict(white_choc_forest, white_choc_X_test, white_predcols)
#       4
#       5 recall = recall_score(white_choc_y_test, y_predicted)
#
# <ipython-input-87-b02b590ffb32> in train_forest(predcols, label_cond, forest_count, custom_df)
#      57     train_data = []
#      58     for attribute in predcols:
# ---> 59         train_data.append(X_train[attribute].values.reshape(X_train_len, 1))
#      60
#      61     # combine training data and flatten label-column to list
#
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# d:\Users\Odin\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'carbohydrates_100g'

# %%
# predict_proba(X)   - predicts probabilities for classification = confidence, I think

#print(food)
for index, value in food['categories_en'].iteritems():
    try:
        if "choco" in value:
            print(value)
    except:
        pass

# %%
print(food)
